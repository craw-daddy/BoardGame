# %%
from classes import User

# %%
crawdaddy = User('craw-daddy')

# %%
crawdaddy.collection
# Out:
#                                                      name             subtype  \
# id
# 122711                                 "La Garde recule!"           boardgame
# 153999                        ...and then, we held hands.           boardgame
# 27236   .45 Adventure: Crimefighting Action in the Pul...           boardgame
# 155122  1066, Tears to Many Mothers: The Battle of Has...           boardgame
# 271270                                         12 Patrols           boardgame
# ...                                                   ...                 ...
# 248861                                    メトロックス (MetroX)           boardgame
# 278585                メトロックス (MetroX): Ishikawa Promo Map  boardgameexpansion
# 181260                                                彩色島           boardgame
# 158600                                               花見小路           boardgame
# 170198                                      開拓王 - もっと建物を！  boardgameexpansion
#
#         yearpublished  own  prevowned  fortrade  want  wanttoplay  wanttobuy  \
# id
# 122711           2011    0          1         0     0           0          0
# 153999           2015    1          0         0     0           0          0
# 27236            2006    1          0         0     0           0          0
# 155122           2018    1          0         0     0           0          0
# 271270           2023    0          0         0     0           0          0
# ...               ...  ...        ...       ...   ...         ...        ...
# 248861           2018    1          0         0     0           0          0
# 278585           2018    1          0         0     0           0          0
# 181260           2015    0          1         0     0           0          0
# 158600           2016    1          0         0     0           0          0
# 170198           2014    1          0         0     0           0          0
#
#         wishlist  preordered        lastmodified  rating  numplays  \
# id
# 122711         0           0 2022-11-13 14:42:41     NaN         0
# 153999         0           0 2015-10-21 14:41:59     NaN         4
# 27236          0           0 2015-01-12 01:53:04     NaN         0
# 155122         0           0 2018-11-30 21:02:41     NaN         0
# 271270         0           1 2023-06-20 11:52:26     NaN         0
# ...          ...         ...                 ...     ...       ...
# 248861         0           0 2019-12-26 13:53:35     8.0        39
# 278585         0           0 2019-12-26 13:56:22     NaN         1
# 181260         0           0 2016-03-10 07:12:22     5.5         2
# 158600         0           0 2016-10-22 08:10:34     NaN         1
# 170198         0           0 2018-02-27 05:32:32     NaN         2
#
#         wishlistpriority                                            comment  \
# id
# 122711                -1                                                NaN
# 153999                -1                                                NaN
# 27236                 -1                                                NaN
# 155122                -1                                                NaN
# 271270                -1                                                NaN
# ...                  ...                                                ...
# 248861                -1  One of the best "roll and write" games I've pl...
# 278585                -1                                                NaN
# 181260                -1  Seems like some good ideas, but definitely not...
# 158600                -1                                                NaN
# 170198                -1                                                NaN
#
#           username
# id
# 122711  craw-daddy
# 153999  craw-daddy
# 27236   craw-daddy
# 155122  craw-daddy
# 271270  craw-daddy
# ...            ...
# 248861  craw-daddy
# 278585  craw-daddy
# 181260  craw-daddy
# 158600  craw-daddy
# 170198  craw-daddy
#
# [2266 rows x 17 columns]

# %%
crawdaddy.refresh_collection()

# %%
crawdaddy.geekbuddies()

# %%
crawdaddy.collection.dtypes

# %%
crawdaddy.filter(subtype='boardgame', yearpublished=2022, own=True)

# %%
crawdaddy.collection.columns

# %%
users = ['russ']

level = 0
while level <= 2 and users:
    print(f'----------  {level}  ---------')
    new_users = []
    for u in users[::-1]:
        print(u)
        person = User(u)
        buddies = person.geekbuddies()
        new_users.extend([i[0] for i in buddies])
        time.sleep(12)
        
    users = new_users
    level += 1
